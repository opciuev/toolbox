# %% [markdown]
# # 第 2 章：Qt 基础对象

# %% [markdown]
# ## 使用说明
#
# 本 notebook 按网页和 PDF 的顺序完整收录 38 个小节、101 个原书代码块。原书代码保存在 Markdown 中；可直接运行的教学补充放在独立代码单元格里。
#
# 覆盖范围：2.1、2.2、2.3、2.3.1、2.3.2、2.3.3、2.3.4、2.4、2.4.1、2.4.2、2.4.3、2.4.4、2.4.5、2.4.6、2.4.7、2.5、2.5.1、2.5.2、2.5.3、2.5.4、2.5.5、2.5.6、2.5.7、2.5.8、2.5.9、2.6、2.6.1、2.6.2、2.6.3、2.7、2.7.1、2.7.2、2.8、2.9、2.10、2.10.1、2.10.2、2.10.3。

# %% [markdown]
# ## 2.1 QObject 类与 Qt 对象模型
#
# 本节在原网页/PDF 中没有独立代码块。

# %% [markdown]
# ## 2.2 建立对象的层级关系
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# # 导入 QObject 类
# from PySide6.QtCore import QObject
#
# # 定义三个类，均派生自 QObject
# class AObject(QObject):
#     # 构造函数
#     def __init__(self, parent=None) -> None:
#         # 调用基类的构造函数
#         super().__init__(parent)
#
# class BObject(QObject):
#     # 构造函数
#     def __init__(self, parent=None) -> None:
#         # 调用基类的构造函数
#         super().__init__(parent)
#
# class CObject(QObject):
#     # 构造函数
#     def __init__(self, parent=None) -> None:
#         # 调用基类的构造函数
#         super().__init__(parent)
# ```
#
# **原书代码块 2**
#
# ```python
# # 创建 AObject 实例，它没有父级对象，parent 参数可忽略
# obj1 = AObject()
#
# # 创建 BObject 实例，它的父级对象是 obj1
# obj2 = BObject(obj1)
#
# # 创建 CObject 实例，它的父级对象也是 obj1
# obj3 = CObject(obj1)
# ```
#
# **原书代码块 3**
#
# ```python
# obj1 = AObject()
# obj2 = BObject()
# obj3 = CObject()
#
# obj2.setParent(obj1)
# obj3.setParent(obj1)
# ```
#
# **原书代码块 4**
#
# ```python
# chdobjs = obj1.findChildren(QObject)
# for obj in chdobjs:
#     print(obj.__class__)
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
from PySide6.QtCore import QObject


class AObject(QObject):
    def __init__(self, parent=None) -> None:
        super().__init__(parent)


class BObject(QObject):
    def __init__(self, parent=None) -> None:
        super().__init__(parent)


class CObject(QObject):
    def __init__(self, parent=None) -> None:
        super().__init__(parent)


obj1 = AObject()
obj2 = BObject(obj1)
obj3 = CObject(obj1)

chdobjs = obj1.findChildren(QObject)
for obj in chdobjs:
    print(obj.__class__)

# %% [markdown]
# ## 2.3 事件与 event 方法
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import *
# from PySide6.QtGui import *
#
# class MyUI(QWindow):
#     # 构造函数
#     def __init__(self, parent=None):
#         super().__init__(parent)
#         # 设置窗口标题
#         self.setTitle("示例程序")
#         # 设置窗口大小
#         self.resize(280, 245)
#
#     # 处理事件
#     def event(self, e: QEvent) -> bool:
#         # 判断是否为键盘按下事件
#         if e.type() == QEvent.KeyPress:
#             keyevent: QKeyEvent = e
#             if keyevent.key() == Qt.Key_Left:
#                 print("你按下了【向左】键")
#             if keyevent.key() == Qt.Key_Right:
#                 print("你按下了【向右】键")
#             if keyevent.key() == Qt.Key_Up:
#                 print("你按下了【向上】键")
#             if keyevent.key() == Qt.Key_Down:
#                 print("你按下了【向下】键")
#             # 已处理过，返回 True
#             return True
#         # 其他事件交由基类去处理
#         return super().event(e)
# ```
#
# **原书代码块 2**
#
# ```python
# if __name__ == "__main__":
#     app = QGuiApplication()
#     obj = MyUI()
#     # 显示窗口
#     obj.show()
#     # 开始消息循环
#     app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_event_method.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3 event() 示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.3.1 接受与忽略事件
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import *
# from PySide6.QtGui import *
# from PySide6.QtWidgets import QWidget, QApplication, QMessageBox
# ```
#
# **原书代码块 2**
#
# ```python
# class MyElement(QWidget):
#     # 构造函数
#     def __init__(self, parent: QWidget = None):
#         super().__init__(parent)
#         # 设置大小
#         self.resize(180, 70)
#
#     # 重写 event 方法
#     def event(self, e: QEvent) -> bool:
#         if e.type() == QEvent.MouseButtonPress:
#             # 忽略此事件
#             e.ignore()
#             return True
#         return super().event(e)
# ```
#
# **原书代码块 3**
#
# ```python
# class MyWindow(QWidget):
#     # 构造函数
#     def __init__(self, parent=None) -> None:
#         super().__init__(parent, Qt.Window)
#         # 窗口标题
#         self.setWindowTitle("示例程序")
#         # 窗口大小
#         self.resize(260, 200)
#
#     # 重写 event 方法
#     def event(self, e: QEvent) -> bool:
#         # 如果是鼠标按下事件
#         if e.type() == QEvent.MouseButtonPress:
#             # 弹出消息框
#             QMessageBox.information(self, "提示", "父窗口接收到鼠标事件", QMessageBox.Ok)
#             # 已处理，返回 True
#             return True
#         return super().event(e)
# ```
#
# **原书代码块 4**
#
# ```python
# if __name__ == "__main__":
#     app = QApplication()
#     # 实例化 MyWindow 类
#     win = MyWindow()
#     # 实例化 MyElement 类，它的父级对象是 win
#     elm = MyElement(win)
#     # 调整可视化对象在窗口上的位置
#     elm.move(36, 30)
#     # 显示窗口
#     win.show()
#     app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_1_accept_ignore.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3.1 接受/忽略事件示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.3.2 sendEvent 与 postEvent
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# class MyWindow(QWidget):
#     # 构造函数
#     def __init__(self):
#         super().__init__(None)
#         # 初始化可视化元素
#         self.initUI()
#         # 窗口标题
#         self.setWindowTitle("发送键盘事件")
#
#     def initUI(self):
#         self.btnSelAll = QPushButton("全选")
#         self.btnDelete = QPushButton("删除")
#         self.btnBackspace = QPushButton("退格")
#         self.btnMoveLeft = QPushButton("<-")
#         self.btnMoveRight = QPushButton("->")
#         self.text = QTextEdit()
#
#         self.grid = QGridLayout(self)
#         self.vbox = QVBoxLayout()
#         self.vbox.addWidget(self.btnSelAll)
#         self.vbox.addWidget(self.btnDelete)
#         self.vbox.addWidget(self.btnBackspace)
#         self.vbox.addWidget(self.btnMoveLeft)
#         self.vbox.addWidget(self.btnMoveRight)
#
#         self.grid.addLayout(self.vbox, 0, 0)
#         self.grid.addItem(QSpacerItem(15, 0), 0, 1)
#         self.grid.addWidget(self.text, 0, 2)
#
#         # 连接信号和槽
#         self.btnSelAll.clicked.connect(self.onSelAll)
#         self.btnDelete.clicked.connect(self.onDel)
#         self.btnBackspace.clicked.connect(self.onBackSpace)
#         self.btnMoveLeft.clicked.connect(self.onMoveLeft)
#         self.btnMoveRight.clicked.connect(self.onMoveRight)
# ```
#
# **原书代码块 2**
#
# ```python
# def onSelAll(self):
#         # Ctrl + A
#         key = Qt.Key_A
#         modf = Qt.ControlModifier
#         # 发送键盘按下事件
#         keyEvt = QKeyEvent(QKeyEvent.KeyPress, key, modf)
#         QApplication.sendEvent(self.text, keyEvt)
#         # 发送键盘释放事件
#         keyEvt = QKeyEvent(QKeyEvent.KeyRelease, key, modf)
#         QApplication.sendEvent(self.text, keyEvt)
#
#     def onDel(self):
#         # Delete
#         key = Qt.Key_Delete
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyPress, key, Qt.NoModifier))
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyRelease, key, Qt.NoModifier))
#
#     def onBackSpace(self):
#         # BackSpace
#         key = Qt.Key_Backspace
#         modif = Qt.NoModifier
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyPress, key, modif))
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyRelease, key, modif))
#
#     def onMoveLeft(self):
#         # Left
#         key = Qt.Key_Left
#         mod = Qt.NoModifier
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyPress, key, mod))
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyRelease, key, mod))
#
#     def onMoveRight(self):
#         # Right
#         key = Qt.Key_Right
#         mod = Qt.NoModifier
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyPress, key, mod))
#         QApplication.sendEvent(self.text, QKeyEvent(QKeyEvent.KeyRelease, key, mod))
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_2_send_event.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3.2 sendEvent/postEvent 示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.3.3 自定义事件
#
# 原书代码块共 7 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# MyCustomEvent1 = QEvent.Type(QEvent.Type.User + 1)
# MyCustomEvent2 = QEvent.Type(QEvent.Type.User + 2)
# ```
#
# **原书代码块 2**
#
# ```python
# def __init__(self):
#     super().__init__(None)
#     # 初始化用户界面
#     self.initUI()
# ```
#
# **原书代码块 3**
#
# ```python
# def initUI(self):
#     # 布局
#     layout = QVBoxLayout(self)
#     # 标签部件
#     self.label = QLabel()
#     # 按钮部件
#     self.btn1 = QPushButton("点这里，触发自定义事件1")
#     self.btn2 = QPushButton("点这里，触发自定义事件2")
#
#     # 将以上部件添加到布局中
#     layout.addWidget(self.label)
#     layout.addWidget(self.btn1)
#     layout.addWidget(self.btn2)
#     # 应用布局
#     self.setLayout(layout)
#
#     # 为按钮的 clicked 信号绑定槽函数
#     self.btn1.clicked.connect(self.onClicked1)
#     self.btn2.clicked.connect(self.onClicked2)
#     # 窗口标题
#     self.setWindowTitle("示例程序")
#     # 窗口大小
#     self.resize(200, 160)
# ```
#
# **原书代码块 4**
#
# ```python
# def onClicked1(self):
#     QApplication.postEvent(self, QEvent(MyCustomEvent1))
#
# def onClicked2(self):
#     QApplication.postEvent(self, QEvent(MyCustomEvent2))
# ```
#
# **原书代码块 5**
#
# ```python
# def event(self, e: QEvent) -> bool:
#     if e.type() == MyCustomEvent1:
#         self.label.setText("自定义事件1已触发")
#         return True
#     if e.type() == MyCustomEvent2:
#         self.label.setText("自定义事件2已触发")
#         return True
#     # 其余事件将交给基类处理
#     return super().event(e)
# ```
#
# **原书代码块 6**
#
# ```python
# QEvent.registerEventType(MyCustomEvent1)
# QEvent.registerEventType(MyCustomEvent2)
# ```
#
# **原书代码块 7**
#
# ```python
# app = QApplication()
# wind = AppWindow()
# wind.show()
# app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_3_custom_event.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3.3 自定义事件示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.3.4 事件过滤器
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# class MyWindow(QWidget):
#     def __init__(self):
#         super().__init__(None, Qt.Window)
#         # 窗口标题
#         self.setWindowTitle("事件过滤")
#         # 窗口大小
#         self.resize(200, 80)
#         # 初始化 UI 部件
#         self.txtEdit = QLineEdit(self)
#         self.txtEdit.move(15, 17)
#         # 安装事件过滤器
#         self.txtEdit.installEventFilter(self)
#
#     def eventFilter(self, watched: QObject, e: QEvent) -> bool:
#         if watched == self.txtEdit:
#             # 检查是否为键盘事件
#             if e.type() == QEvent.KeyPress or e.type() == QEvent.KeyRelease:
#                 keyev = QKeyEvent(e)
#                 # 过滤“空格”键和“#”字符
#                 if keyev.key() == Qt.Key_Space or keyev.key() == Qt.Key_NumberSign:
#                     # 直接返回 True，将跳过该事件
#                     return True
#         return super().eventFilter(watched, e)
# ```
#
# **原书代码块 2**
#
# ```python
# class EventFilter1(QObject):
#     # 构造函数
#     def __init__(self, parent=None):
#         super().__init__(parent)
#
#     # 重写事件过滤方法
#     def eventFilter(self, watched: QObject, e: QEvent) -> bool:
#         if e.type() == QEvent.MouseButtonPress:
#             print("事件过滤器 - 1")
#         return super().eventFilter(watched, e)
#
#
# class EventFilter2(QObject):
#     # 构造函数
#     def __init__(self, parent=None):
#         super().__init__(parent)
#
#     # 重写事件过滤方法
#     def eventFilter(self, watched: QObject, e: QEvent) -> bool:
#         if e.type() == QEvent.MouseButtonPress:
#             print("事件过滤器 - 2")
#         return super().eventFilter(watched, e)
#
#
# class EventFilter3(QObject):
#     # 构造函数
#     def __init__(self, parent=None):
#         super().__init__(parent)
#
#     # 重写事件过滤方法
#     def eventFilter(self, watched: QObject, e: QEvent) -> bool:
#         if e.type() == QEvent.MouseButtonPress:
#             print("事件过滤器 - 3")
#         return super().eventFilter(watched, e)
# ```
#
# **原书代码块 3**
#
# ```python
# class MyWindow(QWidget):
#     def __init__(self) -> None:
#         super().__init__(None, Qt.Window)
#         # 窗口标题
#         self.setWindowTitle("Demo App")
#         # 窗口大小
#         self.resize(240, 70)
#         # 窗口位置
#         self.move(548, 438)
#         # 实例化按钮部件
#         self.btn = QPushButton("请单击这里", self)
#         # 设置按钮的位置
#         self.btn.move(20, 20)
#         # 实例化三个事件过滤器
#         self.evtFilter1 = EventFilter1(self)
#         self.evtFilter2 = EventFilter2(self)
#         self.evtFilter3 = EventFilter3(self)
#         # 注册事件过滤器
#         self.btn.installEventFilter(self.evtFilter1)
#         self.btn.installEventFilter(self.evtFilter2)
#         self.btn.installEventFilter(self.evtFilter3)
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_4_filter_input.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3.4 输入过滤示例', "已启动，进程号：", process.pid)

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.3-事件/2_3_4_filter_order.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.3.4 过滤顺序示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ## 2.4 信号与槽
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# class Demo(QObject):
#     def __init__(self, parent = None):
#         super().__init__(parent)
#
#     # 信号
#     testSignal = Signal()
# ```
#
# **原书代码块 2**
#
# ```python
# def slotFunc():
#     print('已收到信号')
# ```
#
# **原书代码块 3**
#
# ```python
# x = Demo()
# x.testSignal.connect(slotFunc)
# ```
#
# **原书代码块 4**
#
# ```python
# x.testSignal.emit()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
from PySide6.QtCore import QObject, Signal


class Demo(QObject):
    testSignal = Signal()


def slotFunc():
    print("已收到信号")


x = Demo()
x.testSignal.connect(slotFunc)
x.testSignal.emit()

# %% [markdown]
# ### 2.4.1 一个信号连接多个槽
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtWidgets import QWidget, QPushButton, QApplication
#
# # 以下为槽函数
# def func1():
#     print("响应函数：1")
#
# def func2():
#     print("响应函数：2")
#
# def func3():
#     print("响应函数：3")
#
# if __name__ == '__main__':
#     app = QApplication()
#     # 程序窗口
#     window = QWidget(parent=None)
#     # 窗口标题
#     window.setWindowTitle("连接多个槽")
#     # 窗口位置及大小
#     window.setGeometry(766, 550, 230, 90)
#     # 按钮部件
#     button = QPushButton("请单击这里", window)
#     # 按钮在窗口中的位置
#     button.move(25, 20)
#     # clicked 信号连接三个槽对象
#     button.clicked.connect(func1)
#     button.clicked.connect(func2)
#     button.clicked.connect(func3)
#     # 显示窗口
#     window.show()
#     # 启动消息循环
#     app.exec()
# ```
#
# **原书代码块 2**
#
# ```python
# button.clicked.connect(func3)
# button.clicked.connect(func1)
# button.clicked.connect(func2)
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.4-信号与槽/2_4_1_multiple_slots.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.4.1 多槽连接示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.4.2 带参数的信号
#
# 原书代码块共 6 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# class Test(QObject):
#     # 信号
#     setName = Signal(str)
# ```
#
# **原书代码块 2**
#
# ```python
# def onSetName(name):
#     print(f"设置了新名称：{name}")
# ```
#
# **原书代码块 3**
#
# ```python
# x = Test()
# # 连接信号
# x.setName.connect(onSetName)
# # 发出信号
# x.setName.emit("Jack")
# ```
#
# **原书代码块 4**
#
# ```python
# class Test2(QObject):
#     def __init__(self):
#         super().__init__()
#
#     # 信号
#     demoSignal = Signal(int, float)
# ```
#
# **原书代码块 5**
#
# ```python
# def demoSlot(a: int, b: float):
#     print(f'第一个参数：{a:d}')
#     print(f'第二个参数：{b:.3f}')
# ```
#
# **原书代码块 6**
#
# ```python
# v = Test2()
# # 建立连接
# v.demoSignal.connect(demoSlot)
# # 发出信号
# v.demoSignal.emit(300, 100.0830655)
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
from PySide6.QtCore import QObject, Signal


class Test(QObject):
    setName = Signal(str)


def onSetName(name):
    print(f"设置了新名称：{name}")


x = Test()
x.setName.connect(onSetName)
x.setName.emit("Jack")


class Test2(QObject):
    demoSignal = Signal(int, float)


def demoSlot(a: int, b: float):
    print(f"第一个参数：{a:d}")
    print(f"第二个参数：{b:.3f}")


v = Test2()
v.demoSignal.connect(demoSlot)
v.demoSignal.emit(300, 100.0830655)

# %% [markdown]
# ### 2.4.3 使用 C++ 成员方法的签名格式
#
# 原书代码块共 5 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# QSlider::valueChanged(int)
# ```
#
# **原书代码块 2**
#
# ```python
# valueChanged(int)
# ```
#
# **原书代码块 3**
#
# ```python
# onChanged(int)
# ```
#
# **原书代码块 4**
#
# ```python
# from PySide6.QtWidgets import QApplication, QWidget, QLineEdit, QLabel
# from PySide6.QtCore import SIGNAL, SLOT
#
# class AppWindow(QWidget):
#     def __init__(self):
#         super().__init__()
#         # 设置窗口大小
#         self.resize(280, 90)
#         # 设置窗口标题
#         self.setWindowTitle("Demo App")
#         # 初始化单行文本输入部件
#         self.lineTxt = QLineEdit(self)
#         # 建立信号与槽的连接
#         self.lineTxt.connect(SIGNAL('cursorPositionChanged(int,int)'), self,
# SLOT('onCursorPsChanged(int,int)'))
#         # 初始化标签部件
#         self.lb = QLabel(self)
#         # 设置部件在窗口中的位置和大小
#         self.lineTxt.setGeometry(20,15, 200, 25)
#         self.lb.setGeometry(20, 45, 160, 35)
#
#     # 接收 cursorPositionChanged 信号的槽
#     def onCursorPsChanged(self, oldPos, newPos):
#         msg = f'光标已从{oldPos}移动到{newPos}'
#         self.lb.setText(msg)
# ```
#
# **原书代码块 5**
#
# ```python
# if __name__ == '__main__':
#     app = QApplication()
#     window = AppWindow()
#     # 显示窗口
#     window.show()
#     # 启动消息循环
#     app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.4-信号与槽/2_4_3_cpp_signature.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.4.3 C++ 签名连接示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.4.4 信号的类型重载
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# x = Signal((int,), (bytes,))
# ```
#
# **原书代码块 2**
#
# ```python
# x = Signal((int,int,int,), (str,int,))
# ```
#
# **原书代码块 3**
#
# ```python
# from PySide6.QtCore import QObject, Signal
#
# class Demo(QObject):
#     # 信号
#     testSignal = Signal((str, str,), (float,))
#
#     # 槽
#     def testSlot(self, arg1, arg2 = None):
#         if isinstance(arg1, str) and isinstance(arg2, str):
#             print(f'字符串参数：{arg1}、{arg2}')
#         if isinstance(arg1, float):
#             print(f'浮点数参数：{arg1}')
#
#     def __init__(self):
#         super().__init__()
#         # 建立信号和槽之间的连接
#         self.testSignal[str,str].connect(self.testSlot)
#         self.testSignal[float].connect(self.testSlot)
#
#     # 发送信号
#     def sendFloat(self):
#         self.testSignal[float].emit(0.55)
#
#     def sendStr(self):
#         self.testSignal[str,str].emit("hello", "world")
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
from PySide6.QtCore import QObject, Signal


class OverloadDemo(QObject):
    testSignal = Signal((str, str,), (float,))

    def __init__(self):
        super().__init__()
        self.testSignal[str, str].connect(self.testSlot)
        self.testSignal[float].connect(self.testSlot)

    def testSlot(self, arg1, arg2=None):
        if isinstance(arg1, str) and isinstance(arg2, str):
            print(f"字符串参数：{arg1}、{arg2}")
        if isinstance(arg1, float):
            print(f"浮点数参数：{arg1}")

    def sendFloat(self):
        self.testSignal[float].emit(0.55)

    def sendStr(self):
        self.testSignal[str, str].emit("hello", "world")


overload_demo = OverloadDemo()
overload_demo.sendStr()
overload_demo.sendFloat()

# %% [markdown]
# ### 2.4.5 让信号与槽自动建立连接
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# on_<对象名称>_<信号>(<参数列表>)
# ```
#
# **原书代码块 2**
#
# ```python
# class AppWindow(widgets.QWidget):
#     def __init__(self):
#         super().__init__()
#         # 窗口标题
#         self.setWindowTitle('Demo')
#         # 窗口大小
#         self.resize(220, 65)
#         # 初始化按钮部件
#         self.btn = widgets.QPushButton("Click Me", self)
#         # 设置按钮的位置
#         self.btn.move(35,20)
#         # 设置对象的名称
#         self.btn.setObjectName("myButton")
#         # 信号与槽的自动绑定
#         core.QMetaObject.connectSlotsByName(self)
# ......
# ```
#
# **原书代码块 3**
#
# ```python
# @core.Slot()
# def on_myButton_clicked(self):
#     # 弹出消息框
#     widgets.QMessageBox.information(self, "提示", "你单击了按钮", widgets.QMessageBox.Ok)
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.4-信号与槽/2_4_5_auto_connect.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.4.5 自动连接示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.4.6 示例：随机变换窗口的背景颜色
#
# 原书代码块共 5 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# colorList = [
#     QColor(15, 165, 80),
#     QColor(200, 0, 12),
#     QColor(5, 100, 60),
#     QColor(13, 13, 80),
#     QColor(20, 189, 255),
#     QColor(10, 10, 0),
#     QColor(120, 50, 95),
#     QColor(58, 0, 0),
#     QColor(100, 105, 16),
#     QColor(0, 0, 200),
#     QColor(199, 20, 150),
#     QColor(40, 50, 88),
#     QColor(118, 10, 0),
#     QColor(55, 160, 28),
#     QColor(0, 240, 17),
#     QColor(91, 145, 28),
#     QColor(33, 36, 125),
#     QColor(88, 135, 201),
#     QColor(232, 18, 52),
#     QColor(42, 218, 50),
#     QColor(89, 10, 180)
# ]
# ```
#
# **原书代码块 2**
#
# ```python
# class MyWindow(QWidget):
#     # 设置颜色的信号
#     setColor = Signal(QColor)
#
#     # 构造函数
#     def __init__(self):
#         super().__init__()
#         # 窗口标题
#         self.setWindowTitle("随机更换背景色")
#         # 窗口大小
#         self.resize(300, 200)
#         # 初始化按钮部件
#         self.btn = QPushButton("换颜色", self)
#         # 设置按钮位置
#         self.btn.move(15, 15)
#         # 连接 clicked 信号
#         self.btn.clicked.connect(self.onClicked)
#         # 连接 setColor 信号
#         self.setColor.connect(self.onColorPicked)
#
#     # 响应按钮部件的 clicked 信号
#     def onClicked(self):
#         # 随机选一个颜色
#         selColor = choice(colorList)
#         # 发送 setColor 信号
#         self.setColor.emit(selColor)
#
#     # 响应 setColor 信号
#     def onColorPicked(self, color):
#         # 修改当前窗口背景色
#         p = QPalette()
#         p.setColor(QPalette.Window, color)
#         self.setPalette(p)
# ```
#
# **原书代码块 3**
#
# ```python
# p = self.palette()
# p.setColor(QPalette.Window, color)
# self.setPalette(p)
# ```
#
# **原书代码块 4**
#
# ```python
# p = QPalette()
# p.setColor(QPalette.Window, color)
# self.setPalette(p)
# ```
#
# **原书代码块 5**
#
# ```python
# if __name__ == "__main__":
#     app = QApplication()
#     window = MyWindow()          # 实例化窗口
#     window.show()                # 显示窗口
#     app.exec()                   # 开始消息循环
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('demo.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.4.6 随机背景色示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ### 2.4.7 信号阻绝器
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# import PySide6.QtCore as core
# import PySide6.QtWidgets as widgets
# import PySide6.QtGui as gui
#
# class AppWindow(widgets.QWidget):
#     def __init__(self):
#         super().__init__()
#         # 设置窗口标题
#         self.setWindowTitle('My App')
#         # 设置窗口大小
#         self.resize(265, 98)
#         # 初始化按钮部件
#         self.btn = widgets.QPushButton('暂停 10 秒', self)
#         # 设置按钮在窗口中的位置
#         self.btn.move(20,12)
#         # 建立 clicked 信号与槽的连接
#         self.btn.clicked.connect(self.onBtnClicked)
#         # 初始化标签部件
#         self.lb = widgets.QLabel(self)
#         # 设置标签文本
#         self.lb.setText('示例文本')
#         # 设置字体
#         font = gui.QFont('仿宋', 15, gui.QFont.Bold)
#         self.lb.setFont(font)
#         # 设置标签在窗口上的位置
#         self.lb.move(20,50)
#         # 初始化定时器
#         self.timer = core.QTimer(self)
#         # 建立 timeout 信号与槽的连接
#         self.timer.timeout.connect(self.onTimeout)
#         # 启动定时器，每隔 1 秒触发一次
#         self.timer.start(1000)
#
#     # 槽：接收 timeout 信号
#     def onTimeout(self):
#         # 显示或隐藏标签部件
#         if self.lb.isVisible():
#             self.lb.setVisible(False)
#         else:
#             self.lb.setVisible(True)
#
#     # 槽：接收 clicked 信号
#     def onBtnClicked(self):
#         # 阻止定时器上的信号，10 秒后恢复
#         with core.QSignalBlocker(self.timer):
#             # 构建新的事件循环
#             evloop = core.QEventLoop(self)
#             # 启动一次性定时器
#             # 10 秒后执行 quit 方法，退出事件循环
#             core.QTimer.singleShot(10*1000, evloop.quit)
#             # 事件循环开始，exec 方法一直处于等待状态
#             # 直到 quit 方法被调用才会返回
#             # 作用是实现延时 10 秒
#             evloop.exec()
#
# #----------------------------------------------------
# if __name__ == '__main__':
#     app = widgets.QApplication()
#     # 实例化窗口
#     window = AppWindow()
#     # 显示窗口
#     window.show()
#     # 开始消息循环
#     app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
# Notebook 运行补充：本单元格可独立运行，会打开一个单独的进程。
import subprocess
import sys
from pathlib import Path

chapter_folder = '02-Qt基础对象'
relative_path = Path('2.4-信号与槽/2_4_7_signal_blocker.py')
start = Path.cwd().resolve()
chapter_dir = None
for base in (start, *start.parents):
    candidates = [
        base if base.name == chapter_folder else base / chapter_folder,
        base / "章节演示" / chapter_folder,
        base / "PySide6的学习版Web" / "章节演示" / chapter_folder,
    ]
    chapter_dir = next(
        (candidate for candidate in candidates if (candidate / "lesson.ipynb").exists()),
        None,
    )
    if chapter_dir is not None:
        break
if chapter_dir is None:
    raise FileNotFoundError(f"找不到章节目录：{chapter_folder}")

script = chapter_dir / relative_path
process = subprocess.Popen(
    [sys.executable, str(script), *[]],
    cwd=script.parent,
)
print('2.4.7 暂时阻断信号示例', "已启动，进程号：", process.pid)

# %% [markdown]
# ## 2.5 字节序列——QByteArray
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QByteArray
#
# x = QByteArray()
# # 此时序列中没有数据，大小为0
# print(f'初始大小：{x.size()}')
# # 追加3字节数据
# x.append(b'\x25\x6c\x82')
# # 再追加3字节
# x.append(b'\x45\xa6\xd7')
# # 再次打印字节序列的大小
# print(f'追加数据后的大小：{x.size()}')
# # 打印序列中所有字节的十六进制表示方式
# print(f"数据内容：{x.toHex()}")
# ```
#
# **原书代码块 2**
#
# ```python
# x.append(b'\x20\x5f').append(b'\x60').append(b'\xb9\x42')
# ```
#
# **原书代码块 3**
#
# ```python
# def __init__(self, size: int, c: int)
# ```
#
# **原书代码块 4**
#
# ```python
# k = QByteArray(3, 16)
# # 此时初始大小为3
# print(f'初始大小：{k.size()}')
# # 追加5字节
# k.append(b'\x12\x30\x3a\x67\xe4')
# # 原有的3字节加上新的字节，此时大小为8
# print(f'追加数据后的大小：{k.size()}')
# ```

# %% [markdown]
# ### 2.5.1 替换字符串
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# replace(before: Union[QByteArray, bytes], after: Union[QByteArray, bytes]) -> QByteArray
# ```
#
# **原书代码块 2**
#
# ```python
# from PySide6.QtCore import QByteArray
#
# # 创建 QByteArray 对象
# x = QByteArray('fine')
# print(f'原单词：{x.toStdString()}')
# # 被替换的内容
# a = QByteArray('ne')
# # 新内容
# b = QByteArray('sh')
# # 执行替换
# x.replace(a, b)
# print(f'替换后：{x.toStdString()}')
# ```
#
# **原书代码块 3**
#
# ```python
# # 创建新的 QByteArray 实例
# ostr = QByteArray('此心安处是天堂')
# print(f"替换前：{ostr.toStdString()}")
# a = QByteArray('天堂')
# b = QByteArray('吾乡')
# # 替换
# ostr.replace(a, b)
# print(f"替换后：{ostr.toStdString()}")
# ```
#
# **原书代码块 4**
#
# ```python
# # 原字符串，要手动将字符串编码改为 GB2312
# d = QByteArray('一路向南'.encode('gb2312'))
# print(f'替换前：{d.data().decode("gb2312")}')
# # 编码格式要一致
# a = QByteArray('南'.encode('gb2312'))
# b = QByteArray('北'.encode('gb2312'))
# # 替换
# d.replace(a, b)
# print(f'替换后：{d.data().decode("gb2312")}')
# ```

# %% [markdown]
# ### 2.5.2 数值到字符串的转换
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# # 整数值
# num = 28
# # 二进制
# x1 = QByteArray.number(num, base=2)
# print(f'二进制：{x1.toStdString()}')
# # 八进制
# x2 = QByteArray.number(num, base=8)
# print(f'八进制： {x2.toStdString()}')
# # 十进制
# x3 = QByteArray.number(num, base=10)
# print(f'十进制： {x3.toStdString()}')
# # 十六进制
# x4 = QByteArray.number(num, base=16)
# print(f'十六进制：{x4.toStdString()}')
# ```
#
# **原书代码块 2**
#
# ```python
# number(arg__1, format='g', precision=6)
# ```
#
# **原书代码块 3**
#
# ```python
# number = 439.682145
# b = QByteArray.number(number, 'f', 3)
# ```
#
# **原书代码块 4**
#
# ```python
# number = 439.682145
# b = QByteArray.number(number, 'E', 3)    # 结果：4.397E+02
# ```

# %% [markdown]
# ### 2.5.3 字符串到数值的转换
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# # 二进制
# b = QByteArray('1011')
# val, res = b.toInt(2)
# if res:
#     print(val)          # 输出：11
#
# # 十二进制
# b = QByteArray('433')
# val, res = b.toInt(12)
# if res:
#     print(val)          # 输出：615
# ```
#
# **原书代码块 2**
#
# ```python
# # 浮点数值
# b = QByteArray('123.456')
# val, res = b.toFloat()
# if res:
#     print(val)          # 输出：123.45600128173828
#
# # 双精度数值
# b = QByteArray('92998.520453115')
# val, res = b.toDouble()
# if res:
#     print(val)          # 输出：92998.520453115
# ```

# %% [markdown]
# ### 2.5.4 重复字符串
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# x = QByteArray('一二三')
# x = x.repeated(3)
# # 输出：一二三一二三一二三
# print(x.toStdString())
# ```

# %% [markdown]
# ### 2.5.5 数据截取
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# x = QByteArray(b'\x12\x5e\x40\x65\x18\xa1\x7c')
# # 移除后面4字节
# x.chop(4)
# # 打印结果
# msg = ', '.join(f'0x{i:x}' for i in x.data())
# # 输出：0x12, 0x5e, 0x40
# print(msg)
# ```
#
# **原书代码块 2**
#
# ```python
# # 8字节
# arr = QByteArray(b'\xd2\x19\xc3\x55\x28\xe4\x75\x3f')
# # 移除后3字节，并返回新的 QByteArray 实例
# arrc = arr.chopped(3)
# # 输出：0xd2, 0x19, 0xc3, 0x55, 0x28
# print(', '.join(f'0x{i:x}' for i in arrc.data()))
# ```
#
# **原书代码块 3**
#
# ```python
# d = QByteArray(b'\x84\xed\xa6\x9f\x24\x73\xb6')
# # 提取前3字节
# d2 = d.first(3)
# # 输出：0x84, 0xed, 0xa6
# print(', '.join(f'0x{n:x}' for n in d2.data()))
# ```
#
# **原书代码块 4**
#
# ```python
# # 6字节
# x = QByteArray(b'\x66\x32\x8b\x96\x51\x13')
# # 提取最后2字节
# y = x.last(2)
# # 输出：0x51, 0x13
# print(', '.join(f'0x{n:x}' for n in y.data()))
# ```

# %% [markdown]
# ### 2.5.6 切片
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# da = QByteArray('workstation')
# # 切片 1：从第三字节起，连续提取4字节
# sl1 = da.sliced(2, 4)
# # 输出：rkst
# print(sl1.toStdString())
# # 切片 2：从第八字节起提取，直到末尾
# sl2 = da.sliced(7)
# # 输出：tion
# print(sl2.toStdString())
# ```

# %% [markdown]
# ### 2.5.7 Base64 字符串
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# # 原字符串
# arr = QByteArray('watermelon')
# # 获得 Base64 字符串
# bs = arr.toBase64()
# # 输出：d2F0ZXJtZWxvbg==
# print(bs.toStdString())
#
# # 从 Base64 字符串中还原
# arr2 = QByteArray.fromBase64(bs)
# # 输出：watermelon
# print(arr2.toStdString())
# ```
#
# **原书代码块 2**
#
# ```python
# bs = arr.toBase64(QByteArray.OmitTrailingEquals)
# ```
#
# **原书代码块 3**
#
# ```python
# srcData = QByteArray('鸿雁不堪愁里听，云山况是客中过')
# # 编码
# enc = srcData.toBase64(QByteArray.Base64UrlEncoding)
# # 输出：6bi_6ZuB5LiN5aCq5oSB6YeM5ZCs77yM5LqR5bGx5Ya15piv5a6i5Lit6L-H
# print(enc.toStdString())
#
# # 解码
# decData = QByteArray.fromBase64(enc, QByteArray.Base64UrlEncoding)
# # 输出：鸿雁不堪愁里听，云山况是客中过
# print(decData.toStdString())
# ```

# %% [markdown]
# ### 2.5.8 拆分字符串
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# v = QByteArray("D301%542168%K7")
# # 以"%"为分隔符，拆分字符串
# nList = v.split('%')
# # 打印拆分后各部分的内容
# print(*[val.toStdString() for val in nList], sep=', ')
# ```

# %% [markdown]
# ### 2.5.9 频数统计
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# arr = QByteArray('apple and pineapple')
# # 要统计的子串
# key = QByteArray('apple')
# # 统计子串出现的次数
# n = arr.count(key)
# # 输出： apple 出现了 2 次
# print(f'apple 出现了{n}次')
# ```

# %% [markdown]
# ## 2.6 QBuffer
#
# 原书代码块共 4 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# mybuff = QBuffer()
# ```
#
# **原书代码块 2**
#
# ```python
# rootObj = ......
# mybuff = QBuffer(parent=rootObj)
# ```
#
# **原书代码块 3**
#
# ```python
# arr = QByteArray('abc')
# buffer = QBuffer(arr)
# ```
#
# **原书代码块 4**
#
# ```python
# arr = QByteArray('abc')
# buffer = QBuffer()
# buffer.setBuffer(arr)
# ```

# %% [markdown]
# ### 2.6.1 基本的读写操作
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QBuffer
#
# buff = QBuffer()
# # 打开 buffer
# buff.open(QBuffer.WriteOnly)
# # 第一次写入
# buff.write(b'abcd')
# # 第二次写入
# buff.putChar('M')
# # 输出：b'abcdM'
# print(buff.buffer())
# # 使用后可以关闭 buffer
# buff.close()
# ```
#
# **原书代码块 2**
#
# ```python
# buffer = QBuffer()
# if buffer.open(QBuffer.WriteOnly):
#     # 写入10字节
#     buffer.write(b'ktx5dW3Pyb')
# # 关闭 buffer
# buffer.close()
#
# # 以只读方式重新打开 buffer
# if buffer.open(QBuffer.ReadOnly):
#     # 读出5字节
#     data = buffer.read(5)
#     # 输出：b'ktx5d'
#     print(data)
# # 关闭 buffer
# buffer.close()
# ```

# %% [markdown]
# ### 2.6.2 使用已有的 QByteArray 对象
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QByteArray, QBuffer
#
# # 初始数据为"abc"
# arr = QByteArray('abc')
# # 创建 QBuffer 实例
# buff = QBuffer(arr)
# # 打开 QBuffer 对象
# buff.open(QBuffer.Append)
# # 写入"xyz"
# buff.write(b'xyz')
# # 关闭 QBuffer 对象
#
# # 检查一下 QByteArray 对象是否已改变
# # 输出：b'abcxyz'
# print(arr)
# ```

# %% [markdown]
# ### 2.6.3 设置读写位置
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QByteArray, QBuffer
#
# arr = QByteArray('abcdeopq')
# # 输出：abcdeopq
# print(f'原字符串：{arr.toStdString()}')
#
# # 创建 QBuffer 实例
# buffer = QBuffer(arr)
# # 打开 QBuffer 实例
# buffer.open(QBuffer.WriteOnly)
# # 定位读写位置
# buffer.seek(5)
# # 写入4字节
# buffer.write(b'fghi')
# # 关闭 QBuffer 对象
# buffer.close()
# # 输出：abcdefghi
# print(f'写入后：{arr.toStdString()}')
#
# # 读取数据
# bufRead = QBuffer(arr)
# bufRead.open(QBuffer.ReadOnly)
# # 设置读写位置
# bufRead.seek(3)
# # 读入3字节
# arr2 = bufRead.read(3)
# # 输出：def
# print(f'读到的部分内容：{arr2.toStdString()}')
# ```

# %% [markdown]
# ## 2.7 位序列——QBitArray
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# bits = QBitArray(3)
# ```
#
# **原书代码块 2**
#
# ```python
# bits = QBitArray(4, True)
# ```
#
# **原书代码块 3**
#
# ```python
# print(*[bits.at(i) for i in range(0, bits.size())], sep=', ')
# ```

# %% [markdown]
# ### 2.7.1 设置和清除二进制位
#
# 原书代码块共 3 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# bt = QBitArray(4, False)
# # 设置第三个元素的值为 True
# bt.setBit(2)
# # 输出： False, False, True, False
# print(*[bt.at(i) for i in range(0, bt.size())], sep=', ')
# ```
#
# **原书代码块 2**
#
# ```python
# barr = QBitArray(8, True)
# # 将第 2、5、6 个元素的值设置为 False
# barr.setBit(1, False)
# barr.setBit(4, False)
# barr.setBit(5, False)
# # 输出： True, False, True, True, False, False, True, True
# print(*[barr.at(x) for x in range(0, barr.size())], sep=',')
# ```
#
# **原书代码块 3**
#
# ```python
# bitarr = QBitArray(10, True)
# # 清除第 1、3、5、7、9 个元素的值
# bitarr.clearBit(0)
# bitarr.clearBit(2)
# bitarr.clearBit(4)
# bitarr.clearBit(6)
# bitarr.clearBit(8)
# # 输出： False, True, False, True, False, True, False, True, False, True
# elements = [bitarr.at(n) for n in range(0, bitarr.size())]
# print(*elements, sep=', ')
# ```

# %% [markdown]
# ### 2.7.2 频数统计
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# bits = QBitArray(10)
# # 设置第一、四、五、九个元素的值为 True
# bits.setBit(0, True)
# bits.setBit(3, True)
# bits.setBit(4, True)
# bits.setBit(8, True)
# # 统计 False 出现的次数
# n = bits.count(False)
# # 输出： False 出现了 6 次
# print(f"{False}出现了{n}次")
# ```

# %% [markdown]
# ## 2.8 QSysInfo
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QSysInfo
#
# # 系统名称
# sysname = QSysInfo.productType()
# # 系统版本
# sysver = QSysInfo.productVersion()
# # 内核名称
# kername = QSysInfo.kernelType()
# # 内核版本
# kerver = QSysInfo.kernelVersion()
# # CPU 架构
# cpuarch = QSysInfo.currentCpuArchitecture()
# # 打印系统信息
# print(f'系统：{sysname} {sysver}')
# print(f'内核：{kername}({kerver})')
# print(f'CPU架构：{cpuarch}')
# ```

# %% [markdown]
# ## 2.9 Qt 的动态属性
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# obj = QObject()
# # 设置动态属性
# obj.setProperty("prop1", 500)
# obj.setProperty("prop2", 'abc')
# # 获取动态属性的名称列表
# props = obj.dynamicPropertyNames()
# for x in props:
#     # 打印属性名称与对应的值
#     propName = x.toStdString()
#     print(f'{propName} = {obj.property(propName)}')
# ```
#
# **原书代码块 2**
#
# ```python
# from PySide6.QtWidgets import QApplication, QLabel
# from PySide6.QtCore import QSize
#
# if __name__ == '__main__':
#     app = QApplication()
#     lb = QLabel()
#     # 设置属性
#     # windowTitle:    窗口标题
#     # size:           窗口大小
#     # text:           标签上呈现的文本
#     lb.setProperty('windowTitle', 'Demo App')
#     lb.setProperty('size', QSize(250, 130))
#     lb.setProperty('text', '示例文本')
#     lb.show()
#     app.exec()
# ```

# %% [markdown]
# #### 可运行补充
#
# 下面的单元格用于验证本节概念，不替代上方原书代码。

# %%
from PySide6.QtCore import QObject

dynamic_obj = QObject()
dynamic_obj.setProperty("name", "Jack")
dynamic_obj.setProperty("age", 30)

print("name =", dynamic_obj.property("name"))
print("age =", dynamic_obj.property("age"))

# %% [markdown]
# ## 2.10 生成随机数
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QRandomGenerator
#
# # 实例化
# rand = QRandomGenerator()
# n = 0
# while n < 7:
#     # 生成一个随机数
#     r = rand.generate()
#     print(r, end=' ')
#     n += 1
# ```
#
# **原书代码块 2**
#
# ```python
# n = 0
# while n < 7:
#     # 生成一个随机数
#     r = rand.generateDouble()
#     print(r, end=' ')
#     n += 1
# ```

# %% [markdown]
# ### 2.10.1 设置随机数的种子
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# from PySide6.QtCore import QRandomGenerator
#
# def genRandInt():
#     rand = QRandomGenerator()
#     # 生成5个随机数
#     for i in range(0, 5):
#         print(rand.generate(), end=' ')
#     print()     # 换行
#
# if __name__ == "__main__":
#     # 执行三次
#     for x in range(0, 3):
#         genRandInt()
# ```
#
# **原书代码块 2**
#
# ```python
# from PySide6.QtCore import QRandomGenerator, QTime
#
# # 当前时间
# currTime = QTime.currentTime()
# # 0 时
# zero = QTime(0, 0, 0)
# # 得到时差的总秒数
# totalSecs = zero.secsTo(currTime)
# # 实例化 QRandomGenerator
# rand = QRandomGenerator(totalSecs)
# # 生成 5 个随机数
# for i in range(0, 5):
#     n = rand.generate()
#     print(n, end=' ')
# ```

# %% [markdown]
# ### 2.10.2 使用内置的 QRandomGenerator 实例
#
# 原书代码块共 1 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# # 获取全局共享的实例
# rand = QRandomGenerator.global_()
# # 生成9个随机数
# for i in range(1, 10):
#     num = rand.generate()
#     print(num, end='\n' if i % 3 == 0 else ' ')
# ```

# %% [markdown]
# ### 2.10.3 指定随机数的范围
#
# 原书代码块共 2 个，以下按网页/PDF 顺序完整保留。其中有些是局部片段、声明或对照代码，不保证能够单独运行。
#
# **原书代码块 1**
#
# ```python
# rand = QRandomGenerator.global_()
# # 生成 0~99 的随机整数
# nums = []
# for c in range(0, 7):
#     n = rand.bounded(0, 100)
#     nums.append(n)
# # 打印生成的随机数
# # 输出：37, 50, 78, 47, 21, 98, 91
# print(*nums, sep=', ')
# ```
#
# **原书代码块 2**
#
# ```python
# n = rand.bounded(100)
# ```

# %% [markdown]
# ## QtCore 快速验证
#
# 下面把本章几个纯 QtCore 类型放在一个可独立运行的单元格中。

# %%
from PySide6.QtCore import (
    QByteArray,
    QBitArray,
    QBuffer,
    QRandomGenerator,
)

# 2.5.9：QByteArray 频数统计
arr = QByteArray("apple and pineapple")
key = QByteArray("apple")
print(f"apple 出现了 {arr.count(key)} 次")

# 2.6.1：像文件一样读写内存
buffer = QBuffer()
buffer.open(QBuffer.WriteOnly)
buffer.write(b"abcd")
buffer.putChar("M")
print("QBuffer：", buffer.buffer())
buffer.close()

# 2.7.1：设置二进制位
bits = QBitArray(4, False)
bits.setBit(2)
print("QBitArray：", [bits.at(i) for i in range(bits.size())])

# 2.10.3：生成 0～99 的随机整数
rand = QRandomGenerator.global_()
nums = [rand.bounded(0, 100) for _ in range(7)]
print("随机数：", nums)

# %% [markdown]
# ## 小练习
#
# 独立创建一个带字符串信号的对象，连接槽后发送名称。

# %%
from PySide6.QtCore import QObject, Signal


class NameExercise(QObject):
    setName = Signal(str)


def show_name(name: str) -> None:
    print(f"收到新名称：{name}")


exercise = NameExercise()
exercise.setName.connect(show_name)
exercise.setName.emit("小明")

# %% [markdown]
# ## 本章完成标准
#
# 能够运行需要的补充示例，并且在 `章节演示` 目录执行 `python3 check_notebook_coverage.py` 后本章显示 PASS。
